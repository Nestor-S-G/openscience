# %%
import numpy as np
import pandas as pd
import os
import glob

data_path = "/home/nestor/Documentos/UNED/TFM/Craving/DATA_all_experiments_craving_study/All_Experiments"

column_names = ['Trial Number', 'Shot', 'Apprentice', 'Missed', 'Bet', 'Outcome', 
                'Wealth', 'RT', 'Guess', 'Confidence', 'Outcome_Guess', 
                'Sample ID', 'Experiment']

empty = pd.DataFrame(columns = column_names)

for exp in [f.name for f in os.scandir(data_path) if f.is_dir()]:
    for sub in os.listdir(os.path.join(data_path + '/' + exp)):
        x = os.path.join(data_path + '/' + exp + '/' + sub)
        temp = pd.read_excel(x, sheet_name = 'results', header = None, engine = 'xlrd')
        
        if exp in ['DATA_Experiment2', 'DATA_Experiment3', 'DATA_Experiment5']:
            if len(temp.columns) > 11:
                temp = temp.iloc[:,[0, 1] + list(range(3, 12))]
                temp.columns = column_names[:11]
            else:
                temp = temp.iloc[:,[0, 1] + list(range(3, 9))]
                temp.columns = column_names[:8]
                temp[['Guess', 'Confidence', 'Outcome_Guess']] =  pd.DataFrame([[np.nan, np.nan, np.nan]], index=temp.index)
        else:
            if(temp.shape[1] > 7):
                temp = temp.iloc[:,[0, 1] + list(range(3, 8))]
                temp.columns = column_names[:7]
                temp[['RT', 'Guess', 'Confidence', 'Outcome_Guess']] =  pd.DataFrame([[np.nan, np.nan, np.nan, np.nan]], index=temp.index)
            else:
                temp.columns = column_names[:7]
                temp[['RT', 'Guess', 'Confidence', 'Outcome_Guess']] =  pd.DataFrame([[np.nan, np.nan, np.nan, np.nan]], index=temp.index)
        
        temp['Sample ID'] = sub.split('.xls', 1)[0]
        temp['Sample ID'] = temp['Sample ID'].astype('int32')
        temp['Experiment'] = exp.split('DATA_', 1)[1]
            
        empty = pd.concat([empty, temp])


empty.to_csv(data_path + '/RT_Data_all_withRT.csv', index = False, na_rep='NA')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# Cell In[3], line 17
#      15 for sub in os.listdir(os.path.join(data_path + '/' + exp)):
#      16     x = os.path.join(data_path + '/' + exp + '/' + sub)
# ---> 17     temp = pd.read_excel(x, sheet_name = 'results', header = None, engine = 'xlrd')
#      19     if exp in ['DATA_Experiment2', 'DATA_Experiment3', 'DATA_Experiment5']:
#      20         if len(temp.columns) > 11:
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/pandas/util/_decorators.py:296, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     291     msg = (
#     292         f"Starting with Pandas version {version} all arguments of "
#     293         f"{func.__name__}{arguments} will be keyword-only"
#     294     )
#     295     warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/pandas/io/excel/_base.py:304, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     273 @deprecate_nonkeyword_arguments(allowed_args=2, version="2.0")
#     274 @Appender(_read_excel_doc)
#     275 def read_excel(
#    (...)
#     300     mangle_dupe_cols=True,
#     301 ):
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#     307             "Engine should not be specified when passing "
#     308             "an ExcelFile - ExcelFile already has the engine set"
#     309         )
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/pandas/io/excel/_base.py:867, in ExcelFile.__init__(self, path_or_buffer, engine)
#     864 # Always a string
#     865 self._io = stringify_path(path_or_buffer)
# --> 867 self._reader = self._engines[engine](self._io)
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/pandas/io/excel/_xlrd.py:22, in _XlrdReader.__init__(self, filepath_or_buffer)
#      20 err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21 import_optional_dependency("xlrd", extra=err_msg)
# ---> 22 super().__init__(filepath_or_buffer)
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/pandas/io/excel/_base.py:353, in _BaseExcelReader.__init__(self, filepath_or_buffer)
#     351     self.book = self.load_workbook(filepath_or_buffer)
#     352 elif isinstance(filepath_or_buffer, str):
# --> 353     self.book = self.load_workbook(filepath_or_buffer)
#     354 elif isinstance(filepath_or_buffer, bytes):
#     355     self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/pandas/io/excel/_xlrd.py:37, in _XlrdReader.load_workbook(self, filepath_or_buffer)
#      35     return open_workbook(file_contents=data)
#      36 else:
# ---> 37     return open_workbook(filepath_or_buffer)
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/xlrd/__init__.py:148, in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     145     raise XLRDError('ZIP file contents not a known type of workbook')
#     147 from . import book
# --> 148 bk = book.open_workbook_xls(
#     149     filename=filename,
#     150     logfile=logfile,
#     151     verbosity=verbosity,
#     152     use_mmap=use_mmap,
#     153     file_contents=file_contents,
#     154     encoding_override=encoding_override,
#     155     formatting_info=formatting_info,
#     156     on_demand=on_demand,
#     157     ragged_rows=ragged_rows,
#     158 )
#     159 return bk
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/xlrd/book.py:92, in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      90 t1 = perf_counter()
#      91 bk.load_time_stage_1 = t1 - t0
# ---> 92 biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      93 if not biff_version:
#      94     raise XLRDError("Can't determine file's BIFF version")
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/xlrd/book.py:1278, in Book.getbof(self, rqd_stream)
#    1276     bof_error('Expected BOF record; met end of file')
#    1277 if opcode not in bofcodes:
# -> 1278     bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1279 length = self.get2bytes()
#    1280 if length == MY_EOF:
#
# File ~/miniconda3/envs/craving2/lib/python3.9/site-packages/xlrd/book.py:1272, in Book.getbof.<locals>.bof_error(msg)
#    1271 def bof_error(msg):
# -> 1272     raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'\x00\x00\x00\x01Bud1'

# %%
# !which python
# Out:
# /home/nestor/miniconda3/envs/craving2/bin/python
